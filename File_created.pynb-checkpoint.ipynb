# %%
import pandas as pd
import numpy as np

# %%
#Company Coteq
coteq_df1=pd.read_csv('coteq_electricity_2015.csv')
coteq_df2=pd.read_csv('coteq_electricity_2016.csv')
coteq_df3=pd.read_csv('coteq_electricity_2017.csv')
coteq_df4=pd.read_csv('coteq_electricity_2018.csv')
coteq_df5=pd.read_csv('coteq_electricity_2019.csv')

# %%
#Adding Year column in each dataframe
coteq_df1['Year']=2015
coteq_df2['Year']=2016
coteq_df3['Year']=2017
coteq_df4['Year']=2018
coteq_df5['Year']=2019

# %%
final_coteq_df=pd.concat([coteq_df1,coteq_df2,coteq_df3,coteq_df4,coteq_df5], ignore_index=True)

# %%
final_coteq_df
# Out:
#                    net_manager                          purchase_area  \
# 0           Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 1           Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 2           Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 3           Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 4           Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# ...                        ...                                    ...
# 12570  Cogas Infra & Beheer BV  Netbeheerder Centraal Overijssel B.V.
# 12571  Cogas Infra & Beheer BV  Netbeheerder Centraal Overijssel B.V.
# 12572  Cogas Infra & Beheer BV  Netbeheerder Centraal Overijssel B.V.
# 12573  Cogas Infra & Beheer BV  Netbeheerder Centraal Overijssel B.V.
# 12574  Cogas Infra & Beheer BV  Netbeheerder Centraal Overijssel B.V.
#
#               street zipcode_from zipcode_to    city  num_connections  \
# ...

# %%
#Company Coteq
liander_df1=pd.read_csv('liander_electricity_01012015.csv')
liander_df2=pd.read_csv('liander_electricity_01012016.csv')
liander_df3=pd.read_csv('liander_electricity_01012017.csv')
liander_df4=pd.read_csv('liander_electricity_01012018.csv')
liander_df5=pd.read_csv('liander_electricity_01012019.csv')

# %%
#Adding Year column in each dataframe
liander_df1['Year']=2015
liander_df2['Year']=2016
liander_df3['Year']=2017
liander_df4['Year']=2018
liander_df5['Year']=2019

# %%
final_liander_df=pd.concat([liander_df1,liander_df2,liander_df3,liander_df4,liander_df5], ignore_index=True)
final_liander_df
# Out:
#               net_manager purchase_area                  street zipcode_from  \
# 0       Liander N.V. (NW)    Liander NW  De Ruyterkade Steigers       1011AA
# 1       Liander N.V. (NW)    Liander NW           De Ruyterkade       1011AC
# 2       Liander N.V. (NW)    Liander NW          Oosterdokskade       1011AD
# 3       Liander N.V. (NW)    Liander NW       Oosterdokskade AB       1011AE
# 4       Liander N.V. (NW)    Liander NW       Prins Hendrikkade       1011AG
# ...                   ...           ...                     ...          ...
# 703752         Liander NB       LIANDER              De Lauwers       9873RV
# 703753         Liander NB       LIANDER              De Lauwers       9873RW
# 703754         Liander NB       LIANDER              Izermieden       9873TA
# 703755         Liander NB       LIANDER                 Sarabos       9873TH
# 703756         Liander NB       LIANDER            Kolonelsdiep       9873TJ
#
# ...

# %%
final_liander_df.to_csv('liander2015-2019.csv')
final_coteq_df.to_csv('coteq2015-2019.csv')

# %%
final_liander_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703757 entries, 0 to 703756
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   net_manager                   703757 non-null  object
#  1   purchase_area                 264362 non-null  object
#  2   street                        703757 non-null  object
#  3   zipcode_from                  703757 non-null  object
#  4   zipcode_to                    703757 non-null  object
#  5   city                          703757 non-null  object
#  6   num_connections               703757 non-null  float64
#  7   delivery_perc                 703757 non-null  float64
#  8   perc_of_active_connections    703757 non-null  float64
#  9   type_conn_perc                703757 non-null  float64
#  10  type_of_connection            703757 non-null  object
#  11  annual_consume                703757 non-null  float64
# ...

# %%
enexis_df=pd.read_csv(r'enexis_electricity_01012015.csv')
enexis_df1=pd.read_csv(r'enexis_electricity_01012016.csv')
enexis_df2=pd.read_csv(r'enexis_electricity_01012017.csv')
enexis_df3=pd.read_csv(r'enexis_electricity_01012018.csv')
enexis_df4=pd.read_csv(r'enexis_electricity_01012019.csv')

# %%
enexis_df['Year']=2015
enexis_df1['Year']=2016
enexis_df2['Year']=2017
enexis_df3['Year']=2018
enexis_df4['Year']=2019

# %%
final_enexis_df=pd.concat([enexis_df,enexis_df1,enexis_df2,enexis_df3,enexis_df4], ignore_index=True)
final_enexis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588891 entries, 0 to 588890
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   net_manager                   588891 non-null  object
#  1   purchase_area                 588891 non-null  object
#  2   street                        588891 non-null  object
#  3   zipcode_from                  588891 non-null  object
#  4   zipcode_to                    588891 non-null  object
#  5   city                          588891 non-null  object
#  6   delivery_perc                 588309 non-null  float64
#  7   num_connections               588891 non-null  int64
#  8   perc_of_active_connections    588891 non-null  int64
#  9   type_conn_perc                588891 non-null  float64
#  10  type_of_connection            588822 non-null  object
#  11  annual_consume                588891 non-null  float64
# ...

# %%
endinet_df=pd.read_csv(r'endinet_electricity_01012015.csv')
endinet_df1=pd.read_csv(r'endinet_electricity_01012016.csv')

# %%
endinet_df['Year']=2015
endinet_df['Year']=2016

# %%
final_endinet_df=pd.concat([endinet_df,endinet_df1], ignore_index=True)
final_endinet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9115 entries, 0 to 9114
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   net_manager                   9115 non-null   object
#  1   purchase_area                 9115 non-null   int64
#  2   street                        9115 non-null   object
#  3   zipcode_from                  9115 non-null   object
#  4   zipcode_to                    9115 non-null   object
#  5   city                          9115 non-null   object
#  6   num_connections               9115 non-null   float64
#  7   delivery_perc                 9115 non-null   float64
#  8   perc_of_active_connections    9115 non-null   float64
#  9   type_conn_perc                9115 non-null   int64
#  10  type_of_connection            9115 non-null   object
#  11  annual_consume                9115 non-null   int64
# ...

# %%
rendo_df1 = pd.read_csv('rendo_electricity_2015.csv')
rendo_df2 = pd.read_csv('rendo_electricity_2016.csv')
rendo_df3 = pd.read_csv('rendo_electricity_2017.csv')
rendo_df4 = pd.read_csv('rendo_electricity_2018.csv')
rendo_df5 = pd.read_csv('rendo_electricity_2019.csv')

# %%
rendo_df1['year']=2015
rendo_df2['year']=2016
rendo_df3['year']=2017
rendo_df4['year']=2018
rendo_df5['year']=2019

# %%
final_rendo_df=pd.concat([rendo_df1,rendo_df2,rendo_df3,rendo_df4,rendo_df5], ignore_index=True)
final_rendo_df
# Out:
#         net_manager       purchase_area               street zipcode_from  \
# 0     8716912000008  871691280000000008        Stationsplein       7901AA
# 1     8716912000008  871691280000000008       Stationsstraat       7901AB
# 2     8716912000008  871691280000000008         Crerarstraat       7901AC
# 3     8716912000008  871691280000000008         Crerarstraat       7901AD
# 4     8716912000008  871691280000000008         Crerarstraat       7901AE
# ...             ...                 ...                  ...          ...
# 7377  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XK
# 7378  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XL
# 7379  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XM
# 7380  8716912000008  871691280000000008            Leemkoele       8343XN
# 7381  8716912000008  871691280000000008              De Klim       8343XP
#
#      zipcode_to       city  num_connections  delivery_perc  \
# ...

# %%
stedin_df1 = pd.read_csv('stedin_electricity_2015.csv')
stedin_df2 = pd.read_csv('stedin_electricity_2016.csv')
stedin_df3 = pd.read_csv('stedin_electricity_2017.csv')
stedin_df4 = pd.read_csv('stedin_electricity_2018.csv')
stedin_df5 = pd.read_csv('stedin_electricity_2019.csv')

# %%
stedin_df1['year']=2015
stedin_df2['year']=2016
stedin_df3['year']=2017
stedin_df4['year']=2018
stedin_df5['year']=2019

# %%
final_stedin_df=pd.concat([stedin_df1,stedin_df2,stedin_df3,stedin_df4,stedin_df5], ignore_index=True)
final_stedin_df
# Out:
#           net_manager   purchase_area                    street zipcode_from  \
# 0       8716874000009  Stedin Utrecht   Gijsbrecht van Amstelln       1181EJ
# 1       8716874000009  Stedin Utrecht             Rembrandtlaan       1231AC
# 2       8716874000009  Stedin Utrecht             Rembrandtlaan       1231AD
# 3       8716874000009  Stedin Utrecht             Jan Steenlaan       1231AE
# 4       8716874000009  Stedin Utrecht       Pieter de Hooghlaan       1231AG
# ...               ...             ...                       ...          ...
# 418263  8716892000005          Stedin                  Tiendweg       4247EV
# 418264  8716892000005          Stedin       Hooglandse Tiendweg       4247EW
# 418265  8716892000005          Stedin                Vijfmolens       4247EZ
# 418266  8716892000005          Stedin  Burgemeester Schefferhof       4247GA
# 418267  8716892000005  Stedin Utrecht   Meester Vermeulenstraat       4247GC
#
# ...

# %%
endurise_df_2015 = pd.read_csv('enduriselectricity_01012015.csv')
endurise_df_2016 = pd.read_csv('enduriselectricity_01012016.csv')
endurise_df_2017 = pd.read_csv('enduriselectricity_01012017.csv')
endurise_df_2018 = pd.read_csv('enduriselectricity_01012018.csv')
endurise_df_2019 = pd.read_csv('enduriselectricity_01012019.csv')

# %%
endurise_df_2015['Year']=2015
endurise_df_2016['Year']=2016
endurise_df_2017['Year']=2017
endurise_df_2018['Year']=2018
endurise_df_2019['Year']=2019

# %%
final_enduris_df=pd.concat([endurise_df_2015,endurise_df_2016,endurise_df_2017,endurise_df_2018,endurise_df_2019], ignore_index=True)

# %%
final_enduris_df.drop('ï»¿NETBEHEERDER', axis=1)
# Out:
#         net_manager      purchase_area                    street zipcode_from  \
# 0      8.716902e+12  Enduris Netgebied                Poststraat       4301AA
# 1      8.716902e+12  Enduris Netgebied                Poststraat       4301AB
# 2      8.716902e+12  Enduris Netgebied       Korte St. Janstraat       4301AE
# 3      8.716902e+12  Enduris Netgebied                  Fonteine       4301AG
# 4      8.716902e+12  Enduris Netgebied       Lange St. Janstraat       4301AJ
# ...             ...                ...                       ...          ...
# 48474           NaN  Enduris Netgebied                  Hikseweg       4698RJ
# 48475           NaN  Enduris Netgebied           Vogelsangsedijk       4698RK
# 48476           NaN  Enduris Netgebied                Veerstraat       4698RM
# 48477           NaN  Enduris Netgebied                     Haven       4698RN
# 48478           NaN  Enduris Netgebied  Willem van Beierenstraat       4698RT
#
# ...

# %%
westland_df_2015 = pd.read_csv('westland-infra_electricity_2015.csv')
westland_df_2016 = pd.read_csv('westland-infra_electricity_2016.csv')
westland_df_2017 = pd.read_csv('westland-infra_electricity_2017.csv')
westland_df_2018 = pd.read_csv('westland-infra_electricity_2018.csv')
westland_df_2019 = pd.read_csv('westland-infra_electricity_2019.csv')

# %%
westland_df_2015['Year']=2015
westland_df_2016['Year']=2016
westland_df_2017['Year']=2017
westland_df_2018['Year']=2018
westland_df_2019['Year']=2019

# %%
final_westland_df=pd.concat([westland_df_2015,westland_df_2016,westland_df_2017,westland_df_2018,westland_df_2019], ignore_index=True)

# %%
final_endinet_df.to_csv('Consolidated_endinet_2015-2016.csv')
final_enexis_df.to_csv('Consolidated_enexis_2015-2019.csv')
final_rendo_df.to_csv('Consolidated_rendo_2015-2019.csv')
final_stedin_df.to_csv('Consolidated_stedin_2015-2019.csv')
final_westland_df.to_csv('Consolidated_westland.csv')
final_enduris_df.to_csv('Consolidated_enduris.csv')
